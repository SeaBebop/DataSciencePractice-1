# %%
    from pandas import read_csv
from pandas import DataFrame
from pandas import concat
series = read_csv('daily-minimum-temperatures.csv', header=0 ,index_col=0, parse_dates=True, squeeze=True)
temps= DataFrame(series.values)
data= concat([                                                                                         ),temps],axis=1)
data.columns = ['t-2','t-1','t','t+1']
print(data.head(5))
# Out:
#     t-2   t-1     t   t+1
# 0   NaN   NaN   NaN  20.7
# 1   NaN   NaN  20.7  17.9
# 2   NaN  20.7  17.9  18.8
# 3  20.7  17.9  18.8  14.6
# 4  17.9  18.8  14.6  15.8

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
series = read_csv('daily-minimum-temperatures.csv', header=0 ,index_col=0, parse_dates=True, squeeze=True)
temps= DataFrame(series.values)
shifted = temps.shift(1)
window = shifted.rolling(window=2)
means = window.mean()
data= concat([means,temps],axis=1)
data.columns = ['mean(t-1,t','t+1']
print(data.head(5))
# Out:
#    mean(t-1,t   t+1
# 0         NaN  20.7
# 1         NaN  17.9
# 2       19.30  18.8
# 3       18.35  14.6
# 4       16.70  15.8

# %%
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

series = read_csv('daily-minimum-temperatures.csv', header=0 ,index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame()
dataframe['month'] = [series.index[i].month for i in range(len(series))]
dataframe['day'] = [series.index[i].day for i in range(len(series))]
dataframe['temperature'] = [series[i] for i in range(len(series))]
dataframe['year'] = [series.index[i].year for i in range(len(series))]
dataframe.sort_values('month').plot('month','temperature')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

series = read_csv('daily-minimum-temperatures.csv', header=0 ,index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame()
dataframe['month'] = [series.index[i].month for i in range(len(series))]
dataframe['day'] = [series.index[i].day for i in range(len(series))]
dataframe['temperature'] = [series[i] for i in range(len(series))]
dataframe['year'] = [series.index[i].year for i in range(len(series))]
dataframe['temperature'].plot()
#A plot that looks readable until you realize its by y=temperature and x = unordered index values up to 3600
# Out:
# <AxesSubplot:>

# %%
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

series = read_csv('daily-minimum-temperatures.csv', header=0 ,index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame()
dataframe['month'] = [series.index[i].month for i in range(len(series))]
dataframe['day'] = [series.index[i].day for i in range(len(series))]
dataframe['temperature'] = [series[i] for i in range(len(series))]
dataframe['year'] = [series.index[i].year for i in range(len(series))]
dataframe.sort_values('month').plot('month','temperature')
#Really weird plot, can't find a good way to play the month and temperature 
#have to check more
# Out:
# <AxesSubplot:xlabel='month'>

# %%
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

series = read_csv('daily-minimum-temperatures.csv', header=0 ,index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame()
dataframe['month'] = [series.index[i].month for i in range(len(series))]
dataframe['day'] = [series.index[i].day for i in range(len(series))]
dataframe['temperature'] = [series[i] for i in range(len(series))]
dataframe['year'] = [series.index[i].year for i in range(len(series))]
dataframe.sort_values('month')
#In dataframes, you can see they naturally group values with same names
#Group splits them up in this way
dataframe['month'].value_counts()
# Out:
# 8     310
# 10    310
# 1     310
# 3     310
# 5     310
# 7     310
# 12    308
# 4     300
# 6     300
# 9     300
# 11    300
# 2     282
# Name: month, dtype: int64

# %%
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

series = read_csv('daily-minimum-temperatures.csv', header=0 ,index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame()
dataframe['month'] = [series.index[i].month for i in range(len(series))]
dataframe['day'] = [series.index[i].day for i in range(len(series))]
dataframe['temperature'] = [series[i] for i in range(len(series))]
dataframe['year'] = [series.index[i].year for i in range(len(series))]
dataframe.sort_values('month')
#Testing out group functions
groupMonth = dataframe.groupby(['month'])
#This is super important as you can do math for indivdual groups
groupMonth.get_group(1).head(30)
# Out:
#     month  day  temperature  year
# 0       1    1         20.7  1981
# 1       1    2         17.9  1981
# 2       1    3         18.8  1981
# 3       1    4         14.6  1981
# 4       1    5         15.8  1981
# 5       1    6         15.8  1981
# 6       1    7         15.8  1981
# 7       1    8         17.4  1981
# 8       1    9         21.8  1981
# 9       1   10         20.0  1981
# 10      1   11         16.2  1981
# 11      1   12         13.3  1981
# 12      1   13         16.7  1981
# 13      1   14         21.5  1981
# 14      1   15         25.0  1981
# 15      1   16         20.7  1981
# 16      1   17         20.6  1981
# 17      1   18         24.8  1981
# 18      1   19         17.7  1981
# 19      1   20         15.5  1981
# 20      1   21         18.2  1981
# 21      1   22         12.1  1981
# 22      1   23         14.4  1981
# 23      1   24         16.0  1981
# 24      1   25         16.5  1981
# 25      1   26         18.7  1981
# ...

# %%
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

series = read_csv('daily-minimum-temperatures.csv', header=0 ,index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame()
dataframe['month'] = [series.index[i].month for i in range(len(series))]
dataframe['day'] = [series.index[i].day for i in range(len(series))]
dataframe['temperature'] = [series[i] for i in range(len(series))]
dataframe['year'] = [series.index[i].year for i in range(len(series))]
dataframe.sort_values('month')
#Testing out group functions
groupMonth = dataframe.groupby(['month'])
#This is super important as you can do math for indivdual groups
i = 0 
#Tried to make a loop of listed means didnt work
for grp in range(len(groupMonth)):
    groupMonth.get_group(i).mean()
    i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-148-72d1f87a91f3> in <module>
#      17 i = 0
#      18 for grp in range(len(groupMonth)):
# ---> 19     groupMonth.get_group(i).mean()
#      20     i+=1
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     843         inds = self._get_index(name)
#     844         if not len(inds):
# --> 845             raise KeyError(name)
#     846
#     847         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: 0

# %%
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

series = read_csv('daily-minimum-temperatures.csv', header=0 ,index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame()
dataframe['month'] = [series.index[i].month for i in range(len(series))]
dataframe['day'] = [series.index[i].day for i in range(len(series))]
dataframe['temperature'] = [series[i] for i in range(len(series))]
dataframe['year'] = [series.index[i].year for i in range(len(series))]

#Testing out group functions
groupMonth = dataframe.groupby(['month'])
#There are grouped functions, most important is aggregation, which combines the groups
#And within this combined table allows math instructions like mean, median,mode
groupMonth['temperature'].agg(['mean']).round(1)
#Use the round function because on default it does thousands
# Out:
#        mean
# month
# 1      15.0
# 2      15.4
# 3      14.6
# 4      12.1
# 5       9.9
# 6       7.3
# 7       6.7
# 8       7.9
# 9       9.0
# 10     10.3
# 11     12.5
# 12     13.9

# %%
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

series = read_csv('daily-minimum-temperatures.csv', header=0 ,index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame()

#I Swap data around with the code and it seems like from the the cvs it was able to figure out 
#Which is month and temp just from series index, how?
dataframe['temperature'] = [series.index[i].day for i in range(len(series))]
dataframe['day'] = [series.index[i].month for i in range(len(series))]
dataframe['month'] = [series[i] for i in range(len(series))]
dataframe['year'] = [series.index[i].year for i in range(len(series))]

dataframe.head(10)
# Out:
#    temperature  day  month  year
# 0            1    1   20.7  1981
# 1            1    2   17.9  1981
# 2            1    3   18.8  1981
# 3            1    4   14.6  1981
# 4            1    5   15.8  1981
# 5            1    6   15.8  1981
# 6            1    7   15.8  1981
# 7            1    8   17.4  1981
# 8            1    9   21.8  1981
# 9            1   10   20.0  1981

# %%
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

series = read_csv('daily-minimum-temperatures.csv', header=0 ,index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame()

dataframe['month'] = [series.index[i].month for i in range(len(series))]
dataframe['day'] = [series.index[i].day for i in range(len(series))]
dataframe['temperature'] = [series[i] for i in range(len(series))]
dataframe['year'] = [series.index[i].year for i in range(len(series))]

#I figured it out! readcsv has mutiple function members to use that automatically reads a cvs and make columns
#In this case it is parse_dates=True which takes anyform of data that has the syntax of a data
#Then it seperates them into groups such as "1981-01-01" or 30MAR1990 to .month .day .year
#You can customize and define what is a date format is if you want with the .strptime function

#The reason why temperature did not have a .month etc is for its loop is
#Because it is an output seperate from parse_date
#What happens if you have mutiple outputs? The cvs file is read and a series title is given. 
#If cvs file has no titles,panda gives it the title "Unnamed:Series"
dataframe.head(10)
# Out:
#    temperature  day  month  year
# 0            1    1   20.7  1981
# 1            2    1   17.9  1981
# 2            3    1   18.8  1981
# 3            4    1   14.6  1981
# 4            5    1   15.8  1981
# 5            6    1   15.8  1981
# 6            7    1   15.8  1981
# 7            8    1   17.4  1981
# 8            9    1   21.8  1981
# 9           10    1   20.0  1981
